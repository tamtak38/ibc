# %% [markdown]
# <a href="https://colab.research.google.com/github/tamtak38/ibc/blob/master/draw_graph001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set()
sns.set_style("whitegrid")

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
ax.set_xlabel("x-label")
ax.set_ylabel("y-label")
ax.grid(color='b', linestyle='dotted', linewidth=1)
ax.plot([-10.001, 10.001], [0, 0],color="black")
ax.plot([0, 0], [-10.001, 10.001],color="black")
ax.set_xticks(np.arange(-10.001,10.001,1))
ax.set_yticks(np.arange(-10,11,1))
plt.show()
